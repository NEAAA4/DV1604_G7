# %%
import random 
x = [random.randint(-1000, 1000) for _ in range(100)]
y = [random.randint(0,2000) for _ in range(100)]

# %% [markdown]
# Skapa två variabler med random tal i

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
